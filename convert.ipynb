# %%
import pandas as pd

# %%
df = pd.read_csv('Resources/cities.csv')
df.head()
# Out:
#    Unnamed: 0               city  cloudiness  humidity  latitude  longitude  \
# 0           0        provideniya          90        81     64.38    -173.30
# 1           1         chokurdakh          55        31     70.63     147.92
# 2           2  sao joao da barra           0        90    -21.64     -41.05
# 3           3              bowen          98        46    -20.02     148.23
# 4           4       punta arenas           3        92    -53.15     -70.92
#
#    max_temperature  wind_speed country    datetime
# 0            50.00       11.18      RU  1595302095
# 1            83.53       14.41      RU  1595302300
# 2            70.48       10.20      BR  1595302300
# 3            73.40       12.75      AU  1595302300
# 4            30.20        6.93      CL  1595302300

# %%
html = df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>city</th>
#       <th>cloudiness</th>
#       <th>humidity</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>max_temperature</th>
#       <th>wind_speed</th>
#       <th>country</th>
#       <th>datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>provideniya</td>
#       <td>90</td>
#       <td>81</td>
#       <td>64.38</td>
#       <td>-173.30</td>
#       <td>50.00</td>
#       <td>11.18</td>
#       <td>RU</td>
#       <td>1595302095</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>chokurdakh</td>
#       <td>55</td>
#       <td>31</td>
#       <td>70.63</td>
#       <td>147.92</td>
#       <td>83.53</td>
#       <td>14.41</td>
#       <td>RU</td>
#       <td>1595302300</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...
